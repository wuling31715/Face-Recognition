# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.0

# %%
path = "test3.jpg"
image = cv2.imread(path)

# %%
plt.imshow(image)
plt.show()

# %%
BGRflags = [flag for flag in dir(cv2) if flag.startswith('COLOR_BGR') ]
print(BGRflags)
# Out:
# ['COLOR_BGR2BGR555', 'COLOR_BGR2BGR565', 'COLOR_BGR2BGRA', 'COLOR_BGR2GRAY', 'COLOR_BGR2HLS', 'COLOR_BGR2HLS_FULL', 'COLOR_BGR2HSV', 'COLOR_BGR2HSV_FULL', 'COLOR_BGR2LAB', 'COLOR_BGR2LUV', 'COLOR_BGR2Lab', 'COLOR_BGR2Luv', 'COLOR_BGR2RGB', 'COLOR_BGR2RGBA', 'COLOR_BGR2XYZ', 'COLOR_BGR2YCR_CB', 'COLOR_BGR2YCrCb', 'COLOR_BGR2YUV', 'COLOR_BGR2YUV_I420', 'COLOR_BGR2YUV_IYUV', 'COLOR_BGR2YUV_YV12', 'COLOR_BGR5552BGR', 'COLOR_BGR5552BGRA', 'COLOR_BGR5552GRAY', 'COLOR_BGR5552RGB', 'COLOR_BGR5552RGBA', 'COLOR_BGR5652BGR', 'COLOR_BGR5652BGRA', 'COLOR_BGR5652GRAY', 'COLOR_BGR5652RGB', 'COLOR_BGR5652RGBA', 'COLOR_BGRA2BGR', 'COLOR_BGRA2BGR555', 'COLOR_BGRA2BGR565', 'COLOR_BGRA2GRAY', 'COLOR_BGRA2RGB', 'COLOR_BGRA2RGBA', 'COLOR_BGRA2YUV_I420', 'COLOR_BGRA2YUV_IYUV', 'COLOR_BGRA2YUV_YV12']

# %%
t0 = t.time()
cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
t1 = t.time()
dt_cv = t1-t0
print("Conversion took %0.5f seconds" % dt_cv)
# Out:
# Conversion took 0.01148 seconds

# %%
plt.imshow(cv_rgb)
plt.show()

# %%
import dlib

# %%
import face_recognition

# %%
from PIL import Image
import face_recognition

# Load the jpg file into a numpy array
image = face_recognition.load_image_file("test3.jpg")

# Find all the faces in the image using a pre-trained convolutional neural network.
# This method is more accurate than the default HOG model, but it's slower
# unless you have an nvidia GPU and dlib compiled with CUDA extensions. But if you do,
# this will use GPU acceleration and perform well.
# See also: find_faces_in_picture.py
face_locations = face_recognition.face_locations(image, number_of_times_to_upsample=0, model="cnn")

print("I found {} face(s) in this photograph.".format(len(face_locations)))

fig = plt.gcf()
fig.set_size_inches(15, 20)

for face_location, i in zip (face_locations, range(len(face_locations))):
    

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
#     imshow(np.asarray(pil_image))
    ax = plt.subplot(10, 10, 1 + i)
    ax.imshow(np.asarray(pil_image))
plt.show()
# Out:
# I found 17 face(s) in this photograph.
# A face is located at pixel location Top: 636, Left: 331, Bottom: 730, Right: 426
# A face is located at pixel location Top: 876, Left: 878, Bottom: 970, Right: 973
# A face is located at pixel location Top: 612, Left: 484, Bottom: 691, Right: 563
# A face is located at pixel location Top: 644, Left: 620, Bottom: 723, Right: 699
# A face is located at pixel location Top: 700, Left: 1244, Bottom: 779, Right: 1323
# A face is located at pixel location Top: 626, Left: 1675, Bottom: 721, Right: 1770
# A face is located at pixel location Top: 684, Left: 110, Bottom: 778, Right: 205
# A face is located at pixel location Top: 652, Left: 788, Bottom: 731, Right: 867
# A face is located at pixel location Top: 612, Left: 964, Bottom: 691, Right: 1043
# A face is located at pixel location Top: 726, Left: 213, Bottom: 839, Right: 327
# A face is located at pixel location Top: 799, Left: 465, Bottom: 894, Right: 560
# A face is located at pixel location Top: 818, Left: 657, Bottom: 913, Right: 752
# A face is located at pixel location Top: 684, Left: 1132, Bottom: 763, Right: 1211
# A face is located at pixel location Top: 847, Left: 1118, Bottom: 942, Right: 1213
# A face is located at pixel location Top: 693, Left: 1339, Bottom: 788, Right: 1434
# A face is located at pixel location Top: 636, Left: 1532, Bottom: 715, Right: 1611
# A face is located at pixel location Top: 644, Left: 1212, Bottom: 723, Right: 1291

# %%
results

# %%
unknown_face_encoding
# Out:
# []

# %%
unknown_image
# Out:
# array([[[255, 255, 243],
#         [255, 255, 243],
#         [255, 255, 244],
#         ...,
#         [111,  95,  82],
#         [103,  87,  74],
#         [102,  85,  75]],
#
#        [[255, 255, 244],
#         [255, 255, 244],
#         [255, 255, 244],
#         ...,
#         [ 99,  82,  72],
#         [ 95,  78,  68],
#         [ 97,  80,  70]],
#
#        [[255, 255, 244],
#         [255, 255, 244],
#         [255, 255, 244],
#         ...,
#         [100,  83,  73],
#         [103,  86,  76],
#         [108,  91,  81]],
#
#        ...,
#
#        [[ 63,  59,  56],
#         [ 55,  51,  50],
#         [ 53,  47,  49],
#         ...,
#         [221, 199, 188],
#         [218, 196, 185],
#         [214, 192, 181]],
#
#        [[ 64,  60,  59],
#         [ 57,  53,  54],
#         [ 56,  50,  54],
#         ...,
#         [223, 201, 190],
#         [217, 195, 184],
#         [222, 200, 189]],
#
#        [[ 65,  61,  60],
#         [ 63,  59,  60],
#         [ 63,  57,  61],
#         ...,
#         [223, 201, 190],
#         [212, 190, 179],
#         [218, 196, 185]]], dtype=uint8)

# %%
im = Image.open('011.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-489671ccdaf7> in <module>()
# ----> 1 im = Image.open('011.jpg')
#
# NameError: name 'Image' is not defined

# %%
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b4bf6f6511ed> in <module>()
# ----> 1 im
#
# NameError: name 'im' is not defined

# %%
import face_recognition

# Load the jpg files into numpy arrays
biden_image = face_recognition.load_image_file('022.jpg')
biden_image = np.squeeze(biden_image)
obama_image = face_recognition.load_image_file("002.jpg")
unknown_image = face_recognition.load_image_file("003.jpg")

# Get the face encodings for each face in each image file
# Since there could be more than one face in each image, it returns a list of encodings.
# But since I know each image only has one face, I only care about the first encoding in each image, so I grab index 0.
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]
unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]

known_faces = [
    biden_face_encoding,
    obama_face_encoding
]

# results is an array of True/False telling if the unknown face matched anyone in the known_faces array
results = face_recognition.compare_faces(known_faces, unknown_face_encoding)

print("Is the unknown face a picture of Biden? {}".format(results[0]))
print("Is the unknown face a picture of Obama? {}".format(results[1]))
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-252-0e2942e3309f> in <module>()
#      10 # Since there could be more than one face in each image, it returns a list of encodings.
#      11 # But since I know each image only has one face, I only care about the first encoding in each image, so I grab index 0.
# ---> 12 biden_face_encoding = face_recognition.face_encodings(biden_image)[0]
#      13 obama_face_encoding = face_recognition.face_encodings(obama_image)[0]
#      14 unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]
#
# IndexError: list index out of range

# %%
biden_image.shape
# Out:
# (2448, 3264, 3)

# %%
obama_image.shape
# Out:
# (378, 283, 3)

# %%
unknown_image.shape
# Out:
# (354, 283, 3)

# %%
biden_image = face_recognition.load_image_file("001.jpg")

# %%
biden_image
# Out:
# array([[[230, 223, 215],
#         [230, 223, 215],
#         [230, 223, 215],
#         ...,
#         [255, 249, 249],
#         [255, 250, 250],
#         [255, 251, 251]],
#
#        [[230, 223, 215],
#         [230, 223, 215],
#         [230, 223, 215],
#         ...,
#         [255, 250, 250],
#         [255, 251, 251],
#         [255, 252, 252]],
#
#        [[228, 221, 213],
#         [228, 221, 213],
#         [228, 221, 213],
#         ...,
#         [255, 249, 249],
#         [253, 247, 247],
#         [252, 246, 246]],
#
#        ...,
#
#        [[200, 191, 176],
#         [193, 184, 169],
#         [188, 179, 164],
#         ...,
#         [245, 236, 237],
#         [245, 236, 237],
#         [247, 238, 239]],
#
#        [[197, 188, 171],
#         [194, 185, 170],
#         [193, 184, 169],
#         ...,
#         [243, 234, 235],
#         [243, 234, 235],
#         [244, 235, 236]],
#
#        [[198, 189, 174],
#         [196, 187, 172],
#         [195, 186, 171],
#         ...,
#         [244, 235, 236],
#         [244, 235, 236],
#         [244, 235, 236]]], dtype=uint8)

# %%
im = Image.open('011.jpg')
out = im.rotate(270)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960 at 0x116EDD4E0>

# %%
out = im.rotate(270)

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=1280x960 at 0x116EF9588>
